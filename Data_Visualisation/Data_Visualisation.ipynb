# %% [markdown]
# # Data exploration

# %%
import pandas as pd 
import warnings
warnings.filterwarnings("ignore")

# %%
products_data=pd.read_csv('products_data.csv')
products_data1
# Out:
#                                          NameDescription  \
# 0      tungsten solder pick handle solder pick pickin...
# 1      write right  screen protector sony tc screen n...
# 2      casio men dbc databank  digital watch disconti...
# 3      factoryreconditioned dewalt dwkr heavyduty  am...
# 4      energizer   light twoway light feature bright ...
# ...                                                  ...
# 44799  berkley trilene xl  yard fishing line clear  l...
# 44800  badger airbrush company basic spray gun set ea...
# 44801  fimo soft polymer clay  ounces tropical green ...
# 44802  wilton icing color  oz rose petal icing color ...
# 44803  polyform sculpey iii polymer clay  oz french b...
#
#                       categories
# 0          Arts, Crafts & Sewing
# 1      Cell Phones & Accessories
# 2      Clothing, Shoes & Jewelry
# 3       Tools & Home Improvement
# 4         Health & Personal Care
# ...                          ...
# 44799          Sports & Outdoors
# 44800      Arts, Crafts & Sewing
# 44801      Arts, Crafts & Sewing
# 44802     Grocery & Gourmet Food
# 44803      Arts, Crafts & Sewing
#
# [44804 rows x 2 columns]

# %%
import matplotlib.pyplot as plt
import seaborn as sns

cnt_pro = products_data['categories'].value_counts()
plt.figure(figsize=(12,8))
sns.barplot(cnt_pro.index, cnt_pro.values, alpha=0.8)
plt.ylabel('Number of Occurrences', fontsize=12)
plt.xlabel('categories', fontsize=12)
plt.title("Distribution of categories")
plt.xticks(rotation=90)
plt.show();

# %%
import plotly.express as px
fig = px.pie(products_data, names='categories', title ='Pie chart of different categories')
fig.show()
# Out:
# <div>                            <div id="bfa9bd86-f15d-4155-9269-0ed55caa05f9" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("bfa9bd86-f15d-4155-9269-0ed55caa05f9")) {                    Plotly.newPlot(                        "bfa9bd86-f15d-4155-9269-0ed55caa05f9",                        [{"domain":{"x":[0.0,1.0],"y":[0.0,1.0]},"hovertemplate":"categories=%{label}<extra></extra>","labels":["Arts, Crafts & Sewing","Cell Phones & Accessories","Clothing, Shoes & Jewelry","Tools & Home Improvement","Health & Personal Care","Baby Products","Baby Products","Baby","Patio, Lawn & Garden","Baby","Clothing, Shoes & Jewelry","Beauty","Baby","Sports & Outdoors","Electronics","All Electronics","Automotive","All Electronics","Automotive","Beauty","Tools & Home Improvement","Toys & Games","Health & Personal Care","Clothing, Shoes & Jewelry","All Beauty","All Beauty","All Beauty","All Beauty","Baby","Office Products","Electronics","Baby","Office Products","Toys & Games","Electronics","Appliances","Health & Personal Care","Patio, Lawn & Garden","Tools & Home Improvement","Musical Instruments","Electronics","Industrial & Scientific","Appliances","Baby","Office Products","Beauty","Sports & Outdoors","Toys & Games","Industrial & Scientific","All Electronics","Sports & Outdoors","Industrial & Scientific","Appliances","Baby Products","Office Products","Clothing, Shoes & Jewelry","Patio, Lawn & Garden","All Beauty","All Beauty","Baby","Grocery & Gourmet Food","All Beauty","Baby","Appliances","Industrial & Scientific","Industrial & Scientific","Beauty","Cell Phones & Accessories","Beauty","Sports & Outdoors","Appliances","Office Products","Pet Supplies","Electronics","All Electronics","Health & Personal Care","Office Products","Toys & Games","Baby","Arts, Crafts & Sewing","Grocery & Gourmet Food","Clothing, Shoes & Jewelry","All Electronics","Patio, Lawn & Garden","Baby Products","Automotive","Grocery & Gourmet Food","Baby","Grocery & Gourmet Food","All Beauty","Tools & Home Improvement","Health & Personal Care","Cell Phones & Accessories","Musical Instruments","All Electronics","Baby Products","Automotive","Industrial & Scientific","Industrial & Scientific","Sports & Outdoors","Baby","Musical Instruments","Electronics","Arts, Crafts & Sewing","Cell Phones & Accessories","Health & Personal Care","Beauty","Pet Supplies","Musical Instruments","Baby","Health & Personal Care","Beauty","Arts, Crafts & Sewing","Sports & Outdoors","Clothing, Shoes & Jewelry","Industrial & Scientific","Grocery & Gourmet Food","All Electronics","All Beauty","Patio, Lawn & Garden","Pet Supplies","Baby Products","Office Products","All Electronics","Baby Products","Toys & Games","Pet Supplies","Pet Supplies","Pet Supplies","Electronics","All Electronics","Musical Instruments","Industrial & Scientific","Arts, Crafts & Sewing","Arts, Crafts & Sewing","Arts, Crafts & Sewing","Musical Instruments","Health & Personal Care","Patio, Lawn & Garden","Cell Phones & Accessories","Health & Personal Care","Automotive","Musical Instruments","All Beauty","Appliances","Baby","Toys & Games","Baby","Toys & Games","Pet Supplies","Patio, Lawn & Garden","Health & Personal Care","Tools & Home Improvement","Pet Supplies","Health & Personal Care","Office Products","Health & Personal Care","Toys & Games","Beauty","Health & Personal Care","Electronics","Baby Products","Arts, Crafts & Sewing","Musical Instruments","Electronics","Appliances","All Electronics","Health & Personal Care","Musical Instruments","Toys & Games","Arts, Crafts & Sewing","Beauty","Beauty","Toys & Games","All Beauty","Grocery & Gourmet Food","Musical Instruments","Tools & Home Improvement","All Beauty","All Beauty","Electronics","All Beauty","Beauty","Clothing, Shoes & Jewelry","Baby Products","Toy ...

# %% [markdown]
# We observe that our data is balanced, it's aproximately around 4.80%

# %%
products_data.NameDescription.str.len().hist()
# Out:
# <AxesSubplot:>

# %% [markdown]
# We can see that the most NameDescription have a range of 0 to a proximately 1500 characters, while very few NameDescription have 2000 or more characters.

# %%
import itertools
from nltk.tokenize import word_tokenize

# %%
l=[]
for i in range(len(products_data)):
    l.append((word_tokenize(str(products_data1['NameDescription'][i]))))

# %%
from collections import Counter
words_collection = Counter(list(itertools.chain.from_iterable(l)))
freq_word_df = pd.DataFrame(words_collection.most_common(20))
freq_word_df.columns = ['frequently_used_word','count']

freq_word_df.style.background_gradient(cmap='PuBuGn', low=0, high=0, axis=0, subset=None)
# Out:
# <style type="text/css">
# #T_9a23b_row0_col1 {
#   background-color: #014636;
#   color: #f1f1f1;
# }
# #T_9a23b_row1_col1 {
#   background-color: #1e89a7;
#   color: #f1f1f1;
# }
# #T_9a23b_row2_col1 {
#   background-color: #338fbd;
#   color: #f1f1f1;
# }
# #T_9a23b_row3_col1 {
#   background-color: #4c9bc7;
#   color: #f1f1f1;
# }
# #T_9a23b_row4_col1 {
#   background-color: #86b3d5;
#   color: #000000;
# }
# #T_9a23b_row5_col1 {
#   background-color: #b3c3de;
#   color: #000000;
# }
# #T_9a23b_row6_col1 {
#   background-color: #cdd0e5;
#   color: #000000;
# }
# #T_9a23b_row7_col1 {
#   background-color: #d0d1e6;
#   color: #000000;
# }
# #T_9a23b_row8_col1 {
#   background-color: #d2d2e7;
#   color: #000000;
# }
# #T_9a23b_row9_col1 {
#   background-color: #d9d6e9;
#   color: #000000;
# }
# #T_9a23b_row10_col1 {
#   background-color: #e7dfee;
#   color: #000000;
# }
# #T_9a23b_row11_col1 {
#   background-color: #f0e6f2;
#   color: #000000;
# }
# #T_9a23b_row12_col1 {
#   background-color: #f0e7f2;
#   color: #000000;
# }
# #T_9a23b_row13_col1, #T_9a23b_row14_col1 {
#   background-color: #faf1f8;
#   color: #000000;
# }
# #T_9a23b_row15_col1 {
#   background-color: #fbf2f9;
#   color: #000000;
# }
# #T_9a23b_row16_col1, #T_9a23b_row17_col1 {
#   background-color: #fcf4f9;
#   color: #000000;
# }
# #T_9a23b_row18_col1 {
#   background-color: #fdf5fa;
#   color: #000000;
# }
# #T_9a23b_row19_col1 {
#   background-color: #fff7fb;
#   color: #000000;
# }
# </style>
# <table id="T_9a23b">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_9a23b_level0_col0" class="col_heading level0 col0" >frequently_used_word</th>
#       <th id="T_9a23b_level0_col1" class="col_heading level0 col1" >count</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_9a23b_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_9a23b_row0_col0" class="data row0 col0" >inch</td>
#       <td id="T_9a23b_row0_col1" class="data row0 col1" >11959</td>
#     </tr>
#     <tr>
#       <th id="T_9a23b_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_9a23b_row1_col0" class="data row1 col0" >x</td>
#       <td id="T_9a23b_row1_col1" class="data row1 col1" >9809</td>
#     </tr>
#     <tr>
#       <th id="T_9a23b_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_9a23b_row2_col0" class="data row2 col0" >feature</td>
#       <td id="T_9a23b_row2_col1" class="data row2 col1" >9481</td>
#     </tr>
#     <tr>
#       <th id="T_9a23b_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_9a23b_row3_col0" class="data row3 col0" >use</td>
#       <td id="T_9a23b_row3_col1" class="data row3 col1" >9045</td>
#     </tr>
#     <tr>
#       <th id="T_9a23b_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_9a23b_row4_col0" class="data row4 col0" >phone</td>
#       <td id="T_9a23b_row4_col1" class="data row4 col1" >8174</td>
#     </tr>
#     <tr>
#       <th id="T_9a23b_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_9a23b_row5_col0" class="data row5 col0" >color</td>
#       <td id="T_9a23b_row5_col1" class="data row5 col1" >7504</td>
#     </tr>
#     <tr>
#       <th id="T_9a23b_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_9a23b_row6_col0" class="data row6 col0" >easy</td>
#       <td id="T_9a23b_row6_col1" class="data row6 col1" >6965</td>
#     </tr>
#     <tr>
#       <th id="T_9a23b_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_9a23b_row7_col0" class="data row7 col0" >one</td>
#       <td id="T_9a23b_row7_col1" class="data row7 col1" >6919</td>
#     </tr>
#     <tr>
#       <th id="T_9a23b_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_9a23b_row8_col0" class="data row8 col0" >also</td>
#       <td id="T_9a23b_row8_col1" class="data row8 col1" >6876</td>
#     </tr>
#     <tr>
#       <th id="T_9a23b_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_9a23b_row9_col0" class="data row9 col0" >product</td>
#       <td id="T_9a23b_row9_col1" class="data row9 col1" >6668</td>
#     </tr>
#     <tr>
#       <th id="T_9a23b_level0_row10" class="row_heading level0 row10" >10</th>
#       <td id="T_9a23b_row10_col0" class="data row10 col0" >skin</td>
#       <td id="T_9a23b_row10_col1" class="data row10 col1" >6199</td>
#     </tr>
#     <tr>
#       <th id="T_9a23b_level0_row11" class="row_heading level0 row11" >11</th>
#       <td id="T_9a23b_row11_col0" class="data row11 col0" >make</td>
#       <td id="T_9a23b_row11_col1" class="data row11 col1" >5928</td>
#     </tr>
#     <tr>
#       <th id="T_9a23b_level0_row12" class="row_heading level0 row12" >12</th>
#       <td id="T_9a23b_row12_col0" class="data row12 col0" >made</td>
#       <td id="T_9a23b_row12_col1" class="data row12 col1" >5880</td>
#     </tr>
#     <tr>
#       <th id="T_9a23b_level0_row13" class="row_heading level0 row13" >13</th>
#       <td id="T_9a23b_row13_col0" class="data row13 col0" >system</td>
#       <td id="T_9a23b_row13_col1" class="data row13 col1" >5473</td>
#     </tr>
#     <tr>
#       <th id="T_9a23b_level0_row14" class="row_heading level0 row14" >14</th>
#       <td id="T_9a23b_row14_col0" class="data row14 col0" >design</td>
#       <td id="T_9a23b_row14_col1" class="data row14 col1" >5459</td>
#     </tr>
#     <tr>
#       <th id="T_9a23b_level0_row15" class="row_heading level0 row15" >15</th>
#       <td id="T_9a23b_row15_col0" class="data row15 col0" >oz</td>
#       <td id="T_9a23b_row15_col1" class="data row15 col1" >5418</td>
#     </tr>
#     <tr>
#       <th id="T_9a23b_level0_row16" class="row_heading level0 row16" >16</th>
#       <td id="T_9a23b_row16_col0" class="data row16 col0" >time</td>
#       <td id="T_9a23b_row16_col1" class="data row16 col1" >5370</td>
#     </tr>
#     <tr>
#       <th id="T_9a23b_level0_row17" class="row_heading level0 row17" >17</th>
#       <td id="T_9a23b_row17_col0" class="data row17 col0" >baby</td>
#       <td id="T_9a23b_row17_col1" class="data row17 col1" >5366</td>
#     </tr>
#     <tr>
#       <th id="T_9a23b_level0_row18" class="row_heading level0 row18" >18</th>
#       <td id="T_9a23b_row18_col0" class="data row18 col0" >set</td>
#       <td id="T_9a23b_row18_col1" class="data row18 col1" >5304</td>
#     </tr>
#     <tr>
#       <th id="T_9a23b_level0_row19" class="row_heading level0 row19" >19</th>
#       <td id="T_9a23b_row19_col0" class="data row19 col0" >size</td>
#       <td id="T_9a23b_row19_col1" class="data row19 col1" >5222</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# The figure above shows the most frequently words in our data

# %%
# Visualizing data into wordclouds
from wordcloud import WordCloud, STOPWORDS

def wordcount_gen(df, category):
    # Combine all NameCategories
    
    combined_data = " ".join(map(str,[text for text in df[df.categories==category]['NameDescription']]))
    
                          
    # Initialize wordcloud object
    wc = WordCloud(background_color='white', 
                   max_words=50, 
                   stopwords = STOPWORDS)

    # Generate and plot wordcloud
    plt.figure(figsize=(10,10))
    plt.imshow(wc.generate(combined_data))
    plt.title('{} Words'.format(category), fontsize=20)
    plt.axis('off')
    plt.show()

# %%
# rocery & Gourmet Food words
wordcount_gen(products_data, 'Grocery & Gourmet Food')

# %% [markdown]
# The figure above shows the words used to describe 'Grocery & Gourmet Food' category. we can see that the most used words here are flavor, tea, taste ...

# %%
# Sports & Outdoors words
wordcount_gen(products_data, 'Sports & Outdoors')

# %% [markdown]
# The figure above shows the words used to describe 'Sports & Outdoors' category. we can observe that the most used words are feature, ball, black, size...
